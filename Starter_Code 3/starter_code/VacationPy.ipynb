# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import json
import requests

# Import API key
from api_keys import geoapify_key
geoapift_key = "a8ab2f7318a94a208dc28a8c7f72a508"
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("/Users/meganflinders/Desktop/Bootcamp/Repos/python-api-challenge/python-api-challenge/Starter_Code 3/output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         ancud -41.8697  -73.8203     11.77        65           0
# 1        1  punta arenas -53.1500  -70.9167     10.01        66          40
# 2        2         bluff -46.6000  168.3333     13.05        81          97
# 3        3       ushuaia -54.8000  -68.3000     13.81        41           0
# 4        4     ust-kuyga  70.0167  135.6000    -10.53        97         100
#
#    Wind Speed Country        Date
# 0        1.81      CL  1680529667
# 1        5.14      CL  1680529730
# 2        6.08      NZ  1680529749
# 3        6.69      AR  1680529749
# 4        3.36      RU  1680530333

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
#locations = city_data_df[['Lat', 'Lng']].astype(str)
#humidity = city_data_df['Humidity'].astype(str)
humidity_city_map = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    size = 'Humidity',
    hover_cols=['City'],
    color = 'City',
    geo=True,
    tiles = 'OSM'
)
# Display the map
humidity_city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
low_humidity = city_data_df[city_data_df['Humidity'] < 60]
above_15 = low_humidity[low_humidity['Max Temp'] >= 15]
below_30 = above_15[above_15['Max Temp'] < 30]
slow_wind = below_30[below_30['Wind Speed'] < 10]
ideal_city = slow_wind[slow_wind['Cloudiness'] < 50]
# Drop any rows with null values
ideal_city = ideal_city.dropna()

# Display sample data
ideal_city
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 11        11          saint george  37.1041 -113.5841     15.33        43
# 14        14             cape town -33.9258   18.4232     22.84        59
# 36        36                riyadh  24.6877   46.7219     26.08         8
# 116      116        spodnja idrija  46.0319   14.0272     15.62        48
# 122      122              umm lajj  25.0213   37.2685     25.14        55
# 139      139             esmeralda  21.8525  -78.1169     27.70        53
# 148      148             boa vista   2.8197  -60.6733     27.99        54
# 153      153               awjilah  29.1081   21.2869     26.53        31
# 190      190               itabera -23.8619  -49.1372     22.74        57
# 204      204                yulara -25.2406  130.9889     26.17        39
# 214      214              buraydah  26.3260   43.9750     27.25        11
# 223      223                anshun  26.2500  105.9333     21.54        36
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                      City Country      Lat       Lng  Humidity Hotel Name
# 11           saint george      US  37.1041 -113.5841        43
# 14              cape town      ZA -33.9258   18.4232        59
# 36                 riyadh      SA  24.6877   46.7219         8
# 116        spodnja idrija      SI  46.0319   14.0272        48
# 122              umm lajj      SA  25.0213   37.2685        55
# 139             esmeralda      CU  21.8525  -78.1169        53
# 148             boa vista      BR   2.8197  -60.6733        54
# 153               awjilah      LY  29.1081   21.2869        31
# 190               itabera      BR -23.8619  -49.1372        57
# 204                yulara      AU -25.2406  130.9889        39
# 214              buraydah      SA  26.3260   43.9750        11
# 223                anshun      CN  26.2500  105.9333        36
# 234                   gat      IL  31.6100   34.7642        38
# 245                nushki      PK  29.5542   66.0215        21
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
base_url = "https://api.geoapify.com/v2/places"
radius = 5000
params = {
    "types": "lodging",
    "radius": radius,
    "key": geoapify_key
}
name_address = requests.get(base_url, params=params).json()
print(json.dumps(name_address, indent=4, sort_keys = True))
# Out:
# {
#     "error": "Unauthorized",
#     "message": "Invalid apiKey",
#     "statusCode": 401
# }

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "types": "lodging",
    "radius": radius,
    "key": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lng},{lat},{radius}'
    params["bias"] = f'proximity:{lng},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# saint george - nearest hotel: No hotel found
# cape town - nearest hotel: No hotel found
# riyadh - nearest hotel: No hotel found
# spodnja idrija - nearest hotel: No hotel found
# umm lajj - nearest hotel: No hotel found
# esmeralda - nearest hotel: No hotel found
# boa vista - nearest hotel: No hotel found
# awjilah - nearest hotel: No hotel found
# itabera - nearest hotel: No hotel found
# yulara - nearest hotel: No hotel found
# buraydah - nearest hotel: No hotel found
# anshun - nearest hotel: No hotel found
# gat - nearest hotel: No hotel found
# nushki - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: No hotel found
# khorramabad - nearest hotel: No hotel found
# mahon - nearest hotel: No hotel found
# ocampo - nearest hotel: No hotel found
# goya - nearest hotel: No hotel found
# bam - nearest hotel: No hotel found
# vila franca do campo - nearest hotel: No hotel found
# rawson - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
humidity_city_map = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    size = 'Humidity',
    hover_cols=['City', 'Country', 'Hotel Name'],
    color = 'City',
    geo=True,
    tiles = 'OSM'
)

# Display the map
humidity_city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
